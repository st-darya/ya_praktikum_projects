# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Декомпозиция" data-toc-modified-id="Декомпозиция-1">Декомпозиция</a></span><ul class="toc-item"><li><span><a href="#Заказчик:" data-toc-modified-id="Заказчик:-1.1">Заказчик:</a></span></li><li><span><a href="#Цель:" data-toc-modified-id="Цель:-1.2">Цель:</a></span></li><li><span><a href="#Задачи:" data-toc-modified-id="Задачи:-1.3">Задачи:</a></span></li><li><span><a href="#Шаг-1.-Изучение-и-подготовка-данных" data-toc-modified-id="Шаг-1.-Изучение-и-подготовка-данных-1.4">Шаг 1. Изучение и подготовка данных</a></span></li><li><span><a href="#Шаг-2.-Исследовательский-анализ-данных" data-toc-modified-id="Шаг-2.-Исследовательский-анализ-данных-1.5">Шаг 2. Исследовательский анализ данных</a></span></li><li><span><a href="#Шаг-3.-Кластеризация-товаров" data-toc-modified-id="Шаг-3.-Кластеризация-товаров-1.6">Шаг 3. Кластеризация товаров</a></span></li><li><span><a href="#Шаг-4.-Анализ-ключевых-бизнес-метрик-продуктового-ассортимента" data-toc-modified-id="Шаг-4.-Анализ-ключевых-бизнес-метрик-продуктового-ассортимента-1.7">Шаг 4. Анализ ключевых бизнес-метрик продуктового ассортимента</a></span></li><li><span><a href="#Шаг-5.-Статистический-анализ-данных" data-toc-modified-id="Шаг-5.-Статистический-анализ-данных-1.8">Шаг 5. Статистический анализ данных</a></span></li></ul></li><li><span><a href="#1.-Изучение-и-подготовка-данных" data-toc-modified-id="1.-Изучение-и-подготовка-данных-2">1. Изучение и подготовка данных</a></span></li><li><span><a href="#2.-Исследовательский-анализ-данных" data-toc-modified-id="2.-Исследовательский-анализ-данных-3">2. Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#2.1-Работа-с-выбросами" data-toc-modified-id="2.1-Работа-с-выбросами-3.1">2.1 Работа с выбросами</a></span></li><li><span><a href="#2.2-Оценка-временной-динамики" data-toc-modified-id="2.2-Оценка-временной-динамики-3.2">2.2 Оценка временной динамики</a></span></li><li><span><a href="#2.3-Категоризация-ассортимента" data-toc-modified-id="2.3-Категоризация-ассортимента-3.3">2.3 Категоризация ассортимента</a></span></li><li><span><a href="#2.4-Анализ-количественных-характеристик-категорий" data-toc-modified-id="2.4-Анализ-количественных-характеристик-категорий-3.4">2.4 Анализ количественных характеристик категорий</a></span></li></ul></li><li><span><a href="#3.-Кластеризация-товарного-ассортимента" data-toc-modified-id="3.-Кластеризация-товарного-ассортимента-4">3. Кластеризация товарного ассортимента</a></span></li><li><span><a href="#4.-Анализ-ключевых-бизнес-метрик-продуктового-ассортимента" data-toc-modified-id="4.-Анализ-ключевых-бизнес-метрик-продуктового-ассортимента-5">4. Анализ ключевых бизнес-метрик продуктового ассортимента</a></span><ul class="toc-item"><li><span><a href="#4.1-Пользовательская-активность" data-toc-modified-id="4.1-Пользовательская-активность-5.1">4.1 Пользовательская активность</a></span></li><li><span><a href="#4.2-Анализ-количества-заказов" data-toc-modified-id="4.2-Анализ-количества-заказов-5.2">4.2 Анализ количества заказов</a></span></li><li><span><a href="#4.3-Анализ-коммерческих-показателей:-выручка-и-средний-чек" data-toc-modified-id="4.3-Анализ-коммерческих-показателей:-выручка-и-средний-чек-5.3">4.3 Анализ коммерческих показателей: выручка и средний чек</a></span></li></ul></li><li><span><a href="#5.-Статистический-анализ" data-toc-modified-id="5.-Статистический-анализ-6">5. Статистический анализ</a></span><ul class="toc-item"><li><span><a href="#5.1-Взаимосвязь-кластеров" data-toc-modified-id="5.1-Взаимосвязь-кластеров-6.1">5.1 Взаимосвязь кластеров</a></span></li><li><span><a href="#5.2-Статистический-тест-на-равенство-выручек-кластеров" data-toc-modified-id="5.2-Статистический-тест-на-равенство-выручек-кластеров-6.2">5.2 Статистический тест на равенство выручек кластеров</a></span></li><li><span><a href="#5.3-Статистический-тест-на-равенство-среднего-чека-в-кластерах" data-toc-modified-id="5.3-Статистический-тест-на-равенство-среднего-чека-в-кластерах-6.3">5.3 Статистический тест на равенство среднего чека в кластерах</a></span></li></ul></li><li><span><a href="#6.-Выводы-и-рекомендации" data-toc-modified-id="6.-Выводы-и-рекомендации-7">6. Выводы и рекомендации</a></span></li></ul></div>

# %% [markdown]
# # Анализ товарного ассортимента интернет-магазина товаров для дома и быта «Пока все ещё тут»

# %% [markdown]
# ## Декомпозиция

# %% [markdown]
# ### Заказчик:
#
# Категорийный менеджер, который отвечает за развитие товарных позиций в интернет-магазине.
#
# ### Цель:
#
# **Разработать аналитические инструменты для принятия решений по дальнейшему развитию продаваемых позиций.**
#
# ### Задачи:
#
# - Провести исследовательский анализ данных;
# - Сегментировать торговый ассортимент;
# - Сформулировать и проверить статистические гипотезы;
# - Проанализировать ключевые бизнес-метрики по товарному ассортименту и спрогнозировать покупательское поведение;
# - Визуализировать и подготовить дашборд.
#
# ### Шаг 1. Изучение и подготовка данных
#
# - Проверить данные на наличие пропусков и дубликатов;
# - Привести данные к нужным типам.
#
# ### Шаг 2. Исследовательский анализ данных
#
# - Оценить качество и объем данных;
# - Посмотреть на распределения, выявить аномалии, если есть;
# - Оценить динамику продаж по времени;
# - Проанализировать продуктовый ассортимент, выявить основные категории продуктов;
# - Сформулировать предварительные гипотезы.
#
# ### Шаг 3. Кластеризация товаров
#
# - Провести кластеризацию, обозначить основные кластеры продуктов и описать ключевые признаки.
#
# ### Шаг 4. Анализ ключевых бизнес-метрик продуктового ассортимента
#
# - Выявить сезонность продаж;
# - Посчитать количество уникальных пользователей за период (DAU, WAU, MAU) и за сезон;
# - Посчитать количество заказов за сезон и в разбивке по кластерам;
# - Проанализировать динамику среднего чека во времени;
# - Проанализировать динамику среднего чека по кластерам;
# - Посчитать выручку за период и в разбивке по кластерам.
#
# ### Шаг 5. Статистический анализ данных
#
# - Выявить взаоимосвязи между кластерами товаров;
# - Выяснить наиболее и наименее прибыльные кластеры товаров;
# - На основе сезонности популярности тех или иных сегментов товаров, спрогнозировать динамику будущих продаж.

# %% [markdown]
# ## 1. Изучение и подготовка данных

# %%
import pandas as pd
import numpy as np 
from numpy import median

import seaborn as sns
import matplotlib.pyplot as plt

import datetime as dt
import re

from pymystem3 import Mystem
from collections import Counter

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage

import scipy.stats as stats
from scipy import stats as st

import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('whitegrid')
sns.set_palette(sns.color_palette('viridis', 40))

# %%
pd.options.display.max_colwidth = 110

# %%
server_path = '/datasets/ecommerce_dataset.csv'
filename = 'ecommerce_dataset.csv'

try: 
    data = pd.read_csv(server_path, sep=',')
except: 
    data = pd.read_csv(filename, sep=',')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6737 entries, 0 to 6736
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         6737 non-null   int64
#  1   customer_id  6737 non-null   object
#  2   order_id     6737 non-null   int64
#  3   product      6737 non-null   object
#  4   quantity     6737 non-null   int64
#  5   price        6737 non-null   float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 315.9+ KB

# %%
data.head()
# Out:
#          date                           customer_id  order_id  \
# 0  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 1  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 2  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 3  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
# 4  2018100100  ee47d746-6d2f-4d3c-9622-c31412542920     68477
#
#                                               product  quantity  price
# 0     Комнатное растение в горшке Алое Вера, d12, h30         1  142.0
# 1  Комнатное растение в горшке Кофе Арабика, d12, h25         1  194.0
# 2                         Радермахера d-12 см h-20 см         1  112.0
# 3                    Хризолидокарпус Лутесценс d-9 см         1  179.0
# 4                      Циперус Зумула d-12 см h-25 см         1  112.0

# %%
data['date'] = pd.to_datetime(data['date'], format='%Y%m%d%H')

# %%
data['product'] = data['product'].str.lower()
data['product'] = data['product'].replace('ё', 'е', regex=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ***Вывод***

# %% [markdown]
# Данные извлечены и готовы к анализу. Пропусков и дубликатов не обнаружено. Типы данных соответствуют содержимому.

# %% [markdown]
# ## 2. Исследовательский анализ данных

# %% [markdown]
# ### 2.1 Работа с выбросами

# %%
data.describe()
# Out:
#            order_id     quantity         price
# count   6737.000000  6737.000000   6737.000000
# mean   43128.948345     2.501559    462.028499
# std    27899.414662    15.266478    871.296064
# min    12624.000000     1.000000      9.000000
# 25%    14827.000000     1.000000    101.000000
# 50%    68503.000000     1.000000    135.000000
# 75%    70504.000000     1.000000    398.000000
# max    73164.000000  1000.000000  14917.000000

# %%
np.mean(data['quantity']) + np.std(data['quantity']) * 3
# Out:
# 48.297593808058366

# %%
print('Транзакции, количество товаров в которых выше нормы:', data[data['quantity'] > 48].shape[0])
# Out:
# Транзакции, количество товаров в которых выше нормы: 35

# %%
data[data['quantity'] > 48].head()
# Out:
#                    date                           customer_id  order_id  \
# 13  2018-10-01 15:00:00  0948b0c2-990b-4a11-b835-69ac4714b21d     68486
# 160 2018-10-09 09:00:00  c971fb21-d54c-4134-938f-16b62ee86d3b     68580
# 211 2018-10-11 14:00:00  cd09ea73-d9ce-48c3-b4c5-018113735e80     68611
# 212 2018-10-11 14:00:00  cd09ea73-d9ce-48c3-b4c5-018113735e80     68611
# 233 2018-10-12 15:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68623
#
#                                                                                 product  \
# 13   крючок одежный 2-х рожковый серый металлик с полимерным покрытием *тонар*, 1110027
# 160                                         стяжка оконная с болтом ст-55 цинк, 1108354
# 211                                                 крепеж для пружины дверной, 1107055
# 212                пружина дверная 240 мм оцинкованная (д-19 мм) без крепления, 1107014
# 233                                петля приварная гаражная d 14х90 мм с шаром, 1103003
#
# ...

# %%
plt.figure(figsize=(15, 7))
sns.distplot(data['quantity'], bins=20, color='C4')
plt.title('Распределение количества товаров в заказе')
plt.xlabel('Количество товаров')
plt.ylabel('Плотность')
plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.distplot(data['quantity'][data['quantity'] <= 48], bins=20, color='C4')
plt.title('Распределение количества товаров в заказе в рамках статистических показателей')
plt.xlabel('Количество товаров')
plt.ylabel('Плотность')
plt.show()

# %% [markdown]
# Статистические характеристики показывают, что большинство пользователей покупают по одному товару каждого наименования, однако, есть и те, кто закупаются оптом. Количество продуктов одного наименования в их корзине исчисляется сотнями. В среднем, учитывая  аномальные значения, пользователи покупают 2,5 товара. Стандартное отклонение указывает, что большинство покупателей берет не более 48 товаров одного наименования.
#
# На текущем этапе избавляться от них не стоит, будем учитывать их при дальнейшем анализе.

# %%
print('Среднее количество товаров без учета выбросов:', data.query('quantity <= 48')['quantity'].mean())
# Out:
# Среднее количество товаров без учета выбросов: 1.847806624888093

# %%
np.mean(data['price']) + np.std(data['price']) * 3
# Out:
# 3075.7226901762356

# %%
print('Строки, в которых цена товара выше нормы:', data[data['price'] > 3075].shape[0])
# Out:
# Строки, в которых цена товара выше нормы: 156

# %%
data[data['price'] > 3075].head()
# Out:
#                   date                           customer_id  order_id  \
# 19 2018-10-01 21:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 51 2018-10-02 15:00:00  494a90f5-2198-4212-8fc9-e3e22ad7afd9     68505
# 58 2018-10-02 18:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 59 2018-10-02 19:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
# 60 2018-10-02 20:00:00  b731df05-98fa-4610-8496-716ec530a02c     68474
#
#                                                                            product  \
# 19     доска гладильная eurogold professional 130х48 см металлическая сетка 35748w
# 51  ерш для туалета с подставкой malibu фарфор 47х12,5 см белый, spirella, 1001768
# 58     доска гладильная eurogold professional 130х48 см металлическая сетка 35748w
# 59     доска гладильная eurogold professional 130х48 см металлическая сетка 35748w
# 60     доска гладильная eurogold professional 130х48 см металлическая сетка 35748w
#
#     quantity   price
# ...

# %%
plt.figure(figsize=(15, 7))
sns.distplot(data['price'], bins=20, color='C8')
plt.title('Распределение стоимости товаров')
plt.xlabel('Стоимость товаров')
plt.ylabel('Плотность')
plt.show()

# %% [markdown]
# Стоимость товаров в корзине в среднем 463 у.е. По правилу трех сигм 99% купленных товаров не превышают цену в 3083 у.е. Тем не менее, мы так же можем наблюдать выбивающиеся значения - 156 товаров стоят больше обозначенного ценника. В целом, используя внешние данные можно оценить, что такие товары действительно находятся в указанной ценовой категории, поэтому аномалиями их считать не стоит.
#
# *Нужно отметить, что мелкие бытовые принадлежности вроде крючков и крепежей стоят мало, но разбираются в больших количествах, тогда как крупные товары (сумки, тележки) покупаются единоштучно.*

# %% [markdown]
# ### 2.2 Оценка временной динамики

# %% [markdown]
# Добавим в датасет столбцы с разными временными промежутками совершения заказов, посмотрим, данными за какой период мы располагаем и оценим необходимость корректировки данных.

# %%
print('В датасете представлены данные с', data['date'].min(), 'по', data['date'].max())
# Out:
# В датасете представлены данные с 2018-10-01 00:00:00 по 2019-10-31 16:00:00

# %%
data['month'] = data['date'].dt.strftime('%Y-%m')
data['week'] = data['date'].dt.strftime('%Y-%U')
data['day'] = data['date'].dt.dayofweek
data['order_date'] = data['date'].dt.date
data['hour'] = data['date'].dt.hour

# %%
print('Всего уникальных заказов в датасете:', len(data['order_id'].unique()))
# Out:
# Всего уникальных заказов в датасете: 2784

# %%
print('Всего уникальных пользователей в датасете:', len(data['customer_id'].unique()))
# Out:
# Всего уникальных пользователей в датасете: 2451

# %%
customers_m = data.groupby('order_id').agg({'customer_id':'nunique'}).query('customer_id > 1')
customers_m.head()
# Out:
#           customer_id
# order_id
# 14872               2
# 68785               2
# 69283               2
# 69310               2
# 69345               2

# %%
print('Уникальные заказы с разными пользователями:', customers_m.shape[0])
# Out:
# Уникальные заказы с разными пользователями: 29

# %%
data = data.query('order_id not in @customers_m.index')

# %% [markdown]
# Вероятно, из-за системной ошибки в данных оказались уникальные идентификаторы заказов с разными id клиентов. От них мы избавились.

# %%
orders_m = data.groupby('order_id').agg({'order_date':'nunique'}).query('order_date > 1').sort_values(by='order_date', ascending=False)
print('Уникальные заказы с разными датами:', orders_m.shape[0])
# Out:
# Уникальные заказы с разными датами: 165

# %%
orders_m.head()
# Out:
#           order_date
# order_id
# 70960             57
# 14833             22
# 69162             15
# 71148             11
# 13547              7

# %%
data[data['order_id'] == 70960].head()
# Out:
#                     date                           customer_id  order_id  \
# 2589 2019-04-01 16:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2600 2019-04-02 10:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2622 2019-04-03 08:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2718 2019-04-07 15:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
# 2734 2019-04-08 09:00:00  57cc80a2-2610-4eef-9457-e7c3bf0c72f0     70960
#
#                                            product  quantity   price    month  \
# 2589  сумка-тележка 2-х колесная gimi argo красная         1  1087.0  2019-04
# 2600  сумка-тележка 2-х колесная gimi argo красная         1  1087.0  2019-04
# 2622  сумка-тележка 2-х колесная gimi argo красная         1  1087.0  2019-04
# 2718  сумка-тележка 2-х колесная gimi argo красная         1  1087.0  2019-04
# 2734  сумка-тележка 2-х колесная gimi argo красная         1  1087.0  2019-04
#
#          week  day  order_date  hour
# ...

# %%
data[data['order_id'] == 14833].shape[0]
# Out:
# 888

# %% [markdown]
# Есть 164 уникальных id заказов, даты которых повторяются. Так, например, заказ номер 14833 представлен в датасете 22 раза в разные даты и занимает 888 строк. Заказ покупателя номер 70960 с одной сумкой-тележкой повторяется 57 раз. Выглядит как техническая ошибка. Мы не знаем, в какое время действительно был совершен заказ, поэтому оставим последнюю дату.
#
# В таких заказах повторяется номер и набор товарных наименований, поэтому удалим дубликаты в этих категориях, сохранив последние в списке.

# %%
data = data.drop_duplicates(subset=['order_id', 'product'], keep='last', inplace=False)

# %%
data[data['order_id'] == 14833]
# Out:
#                     date                           customer_id  order_id  \
# 5533 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5534 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5535 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5536 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5537 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5538 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5539 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5540 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5541 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5542 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5543 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
# 5544 2019-06-22 06:00:00  1d6c8c1f-a799-4418-9af2-1ded47d7a85c     14833
#
# ...

# %% [markdown]
# Так, в ранее упомянутом заказе осталось 12 товарных наименований и одна дата совершения покупки.

# %%
data.groupby('order_id').agg(
    {'order_date':'nunique', 'product':'count'}).query('order_date > 1').sort_values(by='order_date', ascending=False)
# Out:
#           order_date  product
# order_id
# 68760              3       21
# 14500              2       10
# 14541              2        7
# 68814              2        2
# 69527              2        2
# 69750              2        2
# 69807              2        2
# 70186              2        2
# 70318              2        2
# 70995              2        2
# 71143              2        2
# 71426              2        2

# %%
data[data['order_id'] == 14500]
# Out:
#                    date                           customer_id  order_id  \
# 497 2018-10-28 09:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 499 2018-10-28 09:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 554 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 555 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 556 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 557 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 558 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 559 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 560 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
# 561 2018-10-31 13:00:00  3ee43256-af7d-4036-90d4-eeefa1afc767     14500
#
#                                                                product  \
# 497            рассада зелени для кухни базилик арарат, кассета по 6шт
# ...

# %%
data.shape[0]
# Out:
# 4785

# %% [markdown]
# Тем не менее, у нас есть еще 12 уникальных заказов, где нет повторяющихся наименований товаров. Визуально оценив оставшиеся заказы, мы видим, что даты близко друг к другу. Можно предположить, что транзакции занимали некоторое время, поэтому в логах эти покупки сделаны в разные дни.
#
# Таким образом, у нас осталось 4785 обработанных строки.

# %% [markdown]
# Посмотрим на динамику заказов во времени, чтобы определить как меняется интенсивность спроса в зависимости от сезона.

# %%
data.groupby('order_date').agg({'order_id':'count'}).plot(figsize=(18, 10), color='C8', legend=False)
plt.title('Динамика за весь период')
plt.xlabel('Дата заказа')
plt.show()

# %% [markdown]
# Применяя функцию *count*, мы считаем все купленные наименования товаров в рамках одного заказа. Летние месяцы наиболее благоприятны для садово-ремонтных работ, поэтому и спрос на бытовые товары начинает расти весной. Пик продаж (в количестве проданных наименований товаров) приходится на май-июнь. Учитывая, что в каждом заказе может быть несколько наименований, посмотрим на динамику количества уникальных заказов.

# %%
data.groupby('order_date').agg({'order_id':'nunique'}).plot(figsize=(18, 10), color='C8', legend=False)
plt.title('Динамика количества уникальных заказов за весь период')
plt.xlabel('Дата заказа')
plt.show()

# %% [markdown]
# График рваный и флуктуирующий. От даты к дате число уникальных заказов сильно меняется.

# %%
data.groupby('month').agg({'order_id':'nunique'}).plot(figsize=(18, 9), color='C8', legend=False)
plt.title('Динамика количества уникальных заказов по месяцам')
plt.xlabel('Дата заказа')
plt.show()

# %% [markdown]
# Статистика по месяцам более наглядная и не подтверждает предыдущий вывод. Максимум заказов приходится на декабрь и февраль, а к началу лета график достигает минимальных значений.
#
# *Можно предположить, что заказы, совершенные весной-летом более крупные и насчитывают большее число торговых наименований, тогда как зимой покупают часто, но по мелочи*.

# %% [markdown]
# ### 2.3 Категоризация ассортимента

# %% [markdown]
# Разберемся непосредственно с товарными наименованиями.

# %%
print('Количество уникальных продуктов:', len(data['product'].unique()))
# Out:
# Количество уникальных продуктов: 2329

# %% [markdown]
# Найдено 2329 уникальных продукта. Для удобства и увеличения скорости лемматиизации избавимся от цифр и английских букв в строках.

# %%
data['product_re'] =  data['product'].apply(lambda x: re.sub(r'[^А-Яа-яd -]', '', str(x))) #d для удобства поиска диаметра кашпо комнатных растений

# %%
data['product_re'] = data['product_re'].str.replace('   ', ' ', regex=True)
data['product_re'] = data['product_re'].str.replace('  ', ' ', regex=True)

# %%
data['product_re'] = data['product_re'].str.rstrip()

# %%
data['product_re'].value_counts().head()
# Out:
# пеларгония розебудная укорененный черенок              132
# пеларгония розебудная d d укорененный черенок           64
# сумка-тележка -х колесная синяя                         56
# пеларгония зональная диам см сиреневый полумахровый     52
# сушилка для белья потолочная лиана м                    45
# Name: product_re, dtype: int64

# %%
m = Mystem()
data['lemmas'] = data['product_re'].apply(m.lemmatize)

# %%
lemmas = Counter(data['lemmas'].sum()).most_common()
lemmas
# Out:
# [(' ', 24816),
#  ('\n', 4495),
#  ('см', 2170),
#  ('d', 1276),
#  ('для', 1004),
#  ('пеларгония', 820),
#  ('х', 696),
#  ('рассада', 594),
#  ('- ', 584),
#  ('в', 545),
#  ('л', 502),
#  ('зональный', 487),
#  ('-', 480),
#  ('шт', 461),
#  ('диам', 452),
#  ('с', 413),
#  ('кассета', 396),
#  ('сорт', 360),
#  ('тележка', 344),
#  ('махровый', 340),
#  (' - ', 339),
#  ('черенок', 332),
#  ('укоренять', 330),
#  ('сумка', 312),
#  ('белье', 305),
#  ('красный', 302),
#  ('белый', 300),
#  ('объем', 296),
#  ('горшок', 275),
#  ('сушилка', 273),
#  ('по', 257),
#  ('цветок', 243),
#  ('розебудный', 243),
#  ('доска', 234),
#  ('кухня', 225),
#  ('зелень', 220),
#  ('синий', 200),
#  ('розовый', 194),
#  ('гладильный', 192),
#  ('полумахровый', 185),
#  ('однолетний', 184),
#  ('м', 173),
#  (' -', 172),
#  ('петуния', 171),
#  ('томат', 170),
#  ('россия', 167),
#  ('муляж', 166),
#  ('кг', 162),
#  ('помидор', 162),
#  (' -\n', 153),
#  ('ника', 153),
#  ('и', 151),
# ...

# %%
def lemmas_category(lemmas):
    if ('гладильный' in lemmas) or ('сушилка' in lemmas) or\
    ('одежда' in lemmas) or ('вешалка' in lemmas) or\
    ('подкладка' in lemmas) or ('подрукавник' in lemmas) or\
    ('обувь' in lemmas) or ('плечики' in lemmas) or\
    ('одежный' in lemmas) or ('обувной' in lemmas):
        return 'Для одежды и обуви'
    if ('пружина' in lemmas) or ('петля' in lemmas) or\
    ('проволочный' in lemmas) or ('инструмент' in lemmas) or\
    ('стремянка' in lemmas) or ('корыто' in lemmas) or\
    ('цинк' in lemmas) or ('строительный' in lemmas) or\
    ('сверло' in lemmas) or ('сварка' in lemmas) or ('стяжка' in lemmas) or\
    ('набор' in lemmas) or ('измерительный' in lemmas) or\
    ('длина' in lemmas) or ('батарейка' in lemmas) or\
    ('бензин' in lemmas) or ('шило' in lemmas) or\
    ('сметка' in lemmas) or ('уличный' in lemmas) or ('веревка' in lemmas):
        return 'Стройка и ремонт'
    if ('кружка' in lemmas) or ('лоток' in lemmas) or\
    ('сковорода' in lemmas) or ('сотейник' in lemmas) or ('салатник' in lemmas) or\
    ('кастрюля' in lemmas) or ('котел' in lemmas) or\
    ('овощеварка' in lemmas) or ('мантоварка' in lemmas) or\
    ('соковарка' in lemmas) or ('миска' in lemmas) or\
    ('противень' in lemmas) or ('нож' in lemmas) or\
    ('столовая' in lemmas) or ('столовый' in lemmas) or\
    ('чайный' in lemmas) or ('терка' in lemmas) or\
    ('толкушка' in lemmas) or ('тарелка' in lemmas) or\
    ('термокружок' in lemmas) or ('свч' in lemmas) or\
    ('ложка' in lemmas) or ('банка' in lemmas) or\
    ('крышка' in lemmas) or ('пищевой' in lemmas) or\
    ('овощ' in lemmas) or ('венчик' in lemmas) or\
    ('хлебница' in lemmas) or ('рыбочистка' in lemmas) or\
    ('бокал' in lemmas) or ('фужер' in lemmas) or\
    ('чайный' in lemmas) or ('форма' in lemmas) or\
    ('картофелемялка' in lemmas) or ('ножеточка' in lemmas) or\
    ('бутылка' in lemmas) or ('стакан' in lemmas) or\
    ('лезвие' in lemmas) or ('лопатка' in lemmas) or\
    ('ковш' in lemmas) or ('разделочный' in lemmas) or\
    ('термос' in lemmas) or ('сито' in lemmas) or\
    ('плита' in lemmas) or ('пресс' in lemmas):
        return 'Посуда'
    if ('чайник' in lemmas) and ('эмалированный' in lemmas) or ('заварочный' in lemmas):
        return 'Посуда'
    if ('покрывало' in lemmas) or ('хлопок' in lemmas) or\
    ('салфетка' in lemmas) or ('одеяло' in lemmas) or\
    ('полотенце' in lemmas) or ('подушка' in lemmas) or\
    ('скатерть' in lemmas) or ('плед' in lemmas) or ('халат' in lemmas):
        return 'Текстиль'
    if ('электрический' in lemmas) or ('миксер' in lemmas) or\
    ('фен' in lemmas) or ('паровой' in lemmas) or\
    ('пылесос' in lemmas) or ('весы' in lemmas) or\
    ('светильник' in lemmas):
        return 'Бытовая техника'
    if ('сумка' in lemmas) or ('тележка' in lemmas) or\
    ('кофр' in lemmas) or ('хранение' in lemmas) or\
    ('ящик' in lemmas) or ('коробка' in lemmas) or\
    ('корзина' in lemmas) or ('контейнер' in lemmas) or\
    ('таз' in lemmas) or ('полка' in lemmas) or ('комод' in lemmas):
        return 'Хранение и перемещение'
    if ('цветок' in lemmas) and ('искусственный' in lemmas) or\
    ('композиция' in lemmas) or ('подарочный' in lemmas) or\
    ('открытка' in lemmas) or ('упаковка' in lemmas) or\
    ('новогодний' in lemmas) or ('картина' in lemmas) or\
    ('фотография' in lemmas) or ('муляж' in lemmas):
        return 'Декор, искусственные цветы и подарки'
    if ('рассада' in lemmas) and ('зелень' in lemmas) or ('томат' in lemmas) or\
    ('капуста' in lemmas) or ('перец' in lemmas) or ('огурец' in lemmas) or\
    ('тыква' in lemmas) or ('кабачок' in lemmas) or\
    ('клубника' in lemmas) or ('арбуз' in lemmas) or\
    ('дыня' in lemmas) or ('патиссон' in lemmas) or\
    ('баклажан' in lemmas) or ('земляника' in lemmas) or\
    ('морковь' in lemmas) or ('петрушка' in lemmas) or\
    ('пряный' in lemmas) or ('лекарственный' in lemmas):
        return 'Рассада овощей, фруктов и зелени'
    if ('d' in lemmas) and ('вантуз' in lemmas) or\
    ('d' in lemmas) and ('щетка' in lemmas) or\
    ('d' in lemmas) and ('чехол' in lemmas) or\
    ('d' in lemmas) and ('коврик' in lemmas) or\
    ('d' in lemmas) and ('средство' in lemmas):
        return 'Для чистоты и уборки'
    if ('цветок' in lemmas) and ('рассада' in lemmas) or\
    ('однолетний' in lemmas) or ('многолетний' in lemmas) or\
    ('петуния' in lemmas) or ('черенок' in lemmas) or ('крупноцветковый' in lemmas) or\
    ('цвести' in lemmas) or ('садовый' in lemmas) or ('объем' in lemmas) or\
    ('растение' in lemmas) and ('комнатный' in lemmas) or\
    ('домашний' in lemmas) or ('горшок' in lemmas) or\
    ('кашпо' in lemmas) or ('пеларгония' in lemmas) or ('d' in lemmas): 
        return 'Комнатные растения и рассада садовых цветов'
    if 'кассета' in lemmas:
        return 'Рассада овощей, фруктов и зелени'
    if ('ванный' in lemmas) or ('ванна' in lemmas) or ('ванная' in lemmas) or\
    ('туалет' in lemmas) or ('туалетный' in lemmas) or\
    ('унитазный' in lemmas) or ('унитаз' in lemmas) or\
    ('белье' in lemmas) or ('стиральный' in lemmas) or\
    ('коврик' in lemmas) or ('ковер' in lemmas) or ('вантуз' in lemmas) or\
    ('посуда' in lemmas) or ('мытье' in lemmas) or ('чистка' in lemmas) or\
    ('щетка' in lemmas) or ('мыло' in lemmas) or ('швабра' in lemmas) or\
    ('зубной' in lemmas) or ('кухонный' in lemmas) or\
    ('круглый' in lemmas) or ('чистить' in lemmas) or\
    ('перчатка' in lemmas) or ('деревянный' in lemmas) or\
    ('тряпка' in lemmas) or ('скребок' in lemmas) or\
    ('ведро' in lemmas) or ('карниз' in lemmas) or\
    ('совок' in lemmas) or ('губка' in lemmas) or\
    ('антижир' in lemmas) or ('кольцо') or\
    ('мл' in lemmas) or ('чехол' in lemmas) or\
    ('придверный' in lemmas) or ('средство' in lemmas):
        return 'Для чистоты и уборки'
    
data['product_category'] = data['lemmas'].apply(lemmas_category)

# %%
data['product_category'].value_counts()
# Out:
# Комнатные растения и рассада садовых цветов    1716
# Рассада овощей, фруктов и зелени                688
# Для одежды и обуви                              585
# Для чистоты и уборки                            469
# Хранение и перемещение                          437
# Посуда                                          323
# Декор, искусственные цветы и подарки            297
# Стройка и ремонт                                153
# Текстиль                                         92
# Бытовая техника                                  25
# Name: product_category, dtype: int64

# %%
queries = np.array(data['lemmas'])
for query in queries:
    if 'd' in query:
        print(query)
# Out:
# ['комнатный', ' ', 'растение', ' ', 'в', ' ', 'горшок', ' ', 'алый', ' ', 'вера', ' ', 'd', '\n']
# ['комнатный', ' ', 'растение', ' ', 'в', ' ', 'горшок', ' ', 'кофе', ' ', 'арабика', ' ', 'd', '\n']
# ['радермахер', ' ', 'd', '- ', 'см', ' - ', 'см', '\n']
# ['хризолидокарпус', ' ', 'лутесценс', ' ', 'd', '- ', 'см', '\n']
# ['циперус', ' ', 'зумул', ' ', 'd', '- ', 'см', ' - ', 'см', '\n']
# ['шеффлер', ' ', 'лузеан', ' ', 'd', '- ', 'см', '\n']
# ['юкка', ' ', 'нитчатый', ' ', 'd', '- ', 'см', ' -- ', 'см', '\n']
# ['чехол', ' ', 'd', ' ', 'хлопок', ' ', 'для', ' ', 'доска', ' ', 'х', '-', 'х', ' ', 'см', '\n']
# ['муляж', ' ', 'райский', ' ', 'яблочко', ' ', 'зеленый', ' ', 'шт', ' ', 'полиуретан', ' ', 'd', ' ', 'см', '\n']
# ['муляж', ' ', 'зеленый', ' ', 'яблоко', ' ', 'полиуретан', ' ', 'd', '- ', 'см', '\n']
# ['муляж', ' ', 'клубника', ' ', 'шт', ' ', 'полиуретан', ' ', 'd', '- ', 'см', '\n']
# ...

# %% [markdown]
# С помощью лемматизации выделили 10 категорий товаров. Так, бытовая химия, приспособления для уборки и стирки, аксессуары для душа и ванной относятся к категории *Для чистоты и уборки*, предметы для ухода за одеждой и обувью в категории *Для одежды и обуви*, полки, комоды, корзины, тележки - *Хранение и перемещение*, столовые приборы и кухонная утварь в категории *Посуда* и тд.

# %% [markdown]
# ### 2.4 Анализ количественных характеристик категорий

# %% [markdown]
# Добавим столбец с выручкой по каждой транзакции.

# %%
data['revenue'] = data['price'] * data['quantity']

# %% [markdown]
# Посчитаем количество уникальных заказов в категориях.

# %%
categories = data.groupby('product_category')[['order_id']].nunique().sort_values(by='order_id')
plt.figure(figsize = (14, 14))
plt.pie(categories['order_id'], labels=categories.index, colors=[
    'C0', 'C4', 'C8', 'C12', 'C16', 'C20', 'C24', 'C28', 'C32', 'C36'], autopct='%.1f%%', explode=[0.01]*10, pctdistance=1.05)
plt.title('Уникальные заказы', fontsize=14)
plt.show()

# %% [markdown]
# Клиенты магазина чаще всего покупают комнатные растения и рассаду садовых цветов, а также аксессуары для ухода за одеждой. Меньше всего заказов в категории *Бытовая техника* и *Текстиль*.
#
# Посмотрим на средний ценник в категориях.

# %%
plt.figure(figsize=(15, 11))
sns.barplot(data=data, y='product_category', x='price')
plt.xlabel('Цена')
plt.ylabel('')
plt.title('Средняя стоимость товаров по категориях')
plt.show()

# %% [markdown]
# Самый высокий ценник на товары в категории *Хранение и перемещение* - 1750 у.е. в среднем. Средний ценник в 1000 у.е. превышают товары из категорий *Для одежды и обуви*, *Стройка и ремонт*, *Бытовая техника*. В последних двух заметен значительный разброс цен между товарами.
#
# Меньше всего стоят товары из категорий *Рассада овощей, фруктов и зелени*; *Декор, искусственные цветы и подарки* (около 100 у.е.) и *Комнатные растения и рассада садовых цветов* (менее 200 у.е.)

# %%
quantity_in_orders = data.groupby(['product_category', 'order_id']).agg(
    {'quantity':'sum'}).reset_index()

# %%
plt.figure(figsize=(17, 10))
sns.stripplot(data=quantity_in_orders, x='product_category', y='quantity')
plt.xticks(rotation=45, rotation_mode='anchor', ha='right', fontsize=9)
plt.title('Распределение количества товаров в заказах')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Мы уже отмечали, что в среднем на корзину приходится 1,8 товара одного наименования без учета аномальных значений. 2,5 - полагая, что некоторые товары пользователи покупали оптом. В разрезе по категориям заметно, какие товары чаще берут в больших количествах.
#
# Выбросы наблюдаются в категориях *Декор, искусственные цветы и подарки*, *Для одежды и обуви*, *Для чистоты и уборки* (здесь самый крупный выброс в 1000 штук в заказе) и *Стройка и ремонт*.

# %%
data[data['quantity'] > 48]['product_category'].value_counts()
# Out:
# Стройка и ремонт                        8
# Для чистоты и уборки                    7
# Декор, искусственные цветы и подарки    7
# Для одежды и обуви                      4
# Посуда                                  3
# Текстиль                                1
# Хранение и перемещение                  1
# Name: product_category, dtype: int64

# %%
revenue_cat = data.groupby('product_category').agg({'revenue':'mean'}).reset_index()
plt.figure(figsize=(15, 11))
sns.barplot(data=data, y='product_category', x='revenue')
plt.xlabel('')
plt.ylabel('')
plt.title('Средняя выручка в категориях')
plt.show()

# %%
data[data['product_category'] == 'Для чистоты и уборки'].sort_values(by='revenue', ascending=False).head()
# Out:
#                     date                           customer_id  order_id  \
# 5456 2019-06-18 15:00:00  312e9a3e-5fca-43ff-a6a1-892d2b2d5ba6     71743
# 1728 2019-02-07 09:00:00  af4d270b-c7ae-4af5-9582-4e61ff08eff0     70135
# 375  2018-10-23 11:00:00  4d93d3f6-8b24-403b-a74b-f5173e40d7db     68727
# 693  2018-11-07 19:00:00  6ae61023-9d87-4ff3-a02e-b42eab150140     68908
# 2976 2019-04-20 08:00:00  16838b36-762a-474d-bda4-bad95f8d7813     71209
#
#                                                                  product  \
# 5456   вантуз с деревянной ручкой d14 см красный, burstenmann, 0522/0000
# 1728     веник сорго с деревянной ручкой с 4-мя швами, rozenbal, r206204
# 375      веник сорго с деревянной ручкой с 4-мя швами, rozenbal, r206204
# 693         коврик придверный attribute nature кокосовый 60x40 см amc015
# 2976  автоматическая щетка leifheit для мытья окон с ручкой 43 см. 51114
#
#       quantity   price    month     week  day  order_date  hour  \
# ...

# %% [markdown]
# Самая большая средняя выручка с товаров в категории *Текстиль*, *Хранение и перемещение*, *Стройка и ремонт*. В этих же категориях и довольно высокий ценник.
#
# Минимальная - *Рассада овощей, фруктов и зелени* и *Комнатные растения и рассада садовых цветов*. Вероятно, это связано с тем, что в одной корзине обычно оказывается несколько пакетиков с семенами разнообразных плодов.
#
# Сильный разброс цен наблюдается в категории *Для чистоты и уборки* - тысяча одномоментно купленных вантузов сильно перевешивает среднюю выручку в этой категории.

# %% [markdown]
# ***Вывод***

# %% [markdown]
# В ходе анализа выделили 10 категорий товаров:
#
# - *Рассада овощей, фруктов и зелени*
# - *Комнатные растения и рассада садовых цветов*
# - *Декор, искусственные цветы и подарки*
# - *Товары для ухода за одеждой и обувью*
# - *Товары для строительства и ремонта*
# - *Бытовая техника*
# - *Хранение и перемещение*
# - *Товары для чистоты и уборки*
# - *Посуда и кухонная утварь*
# - *Текстиль*
#
# Клиенты магазина чаще всего покупают комнатные растения и рассаду садовых цветов, а также аксессуары для ухода за одеждой. Меньше всего заказов в категории *Бытовая техника* и *Текстиль*.
#
# Самый высокий ценник на товары в категории *Хранение и перемещение* - 1700 у.е. в среднем. Средний ценник в 1000 у.е. превышают товары из категорий *Для одежды и обуви, Стройка и ремонт, Бытовая техника*. В последних двух заметен значительный разброс цен между товарами. Меньше всего стоят товары из категорий *Рассада овощей, фруктов и зелени; Декор, искусственные цветы и подарки (около 100 у.е.) и Комнатные растения и рассада садовых цветов (менее 200 у.е.)*.
#
# Стоимость товаров в корзине в среднем 462 у.е. Большинство купленных товаров не превышают цену в 3075 у.е. Тем не менее, мы так же можем наблюдать выбивающиеся значения - 156 товаров стоят больше обозначенного ценника.
#
# Товары некоторых категорий берут в больших количествах чаще, чем других, а в одном заказе может быть несколько наименований, купленных оптом.
#
# Пик продаж (в количестве проданных наименований товаров) приходится на май-июнь. Максимум уникальных заказов приходится на декабрь и февраль.
#
#
# Таким образом, мы можем сформулировать ряд гипотез.
#
# - Товары с меньшей ценой чаще покупают в больших количествах, а крупные покупки совершают реже.
#
# - Заказы, совершенные весной-летом более крупные и насчитывают большее число торговых наименований, тогда как зимой покупают часто, но по мелочи.
#
# - Некоторые товары обладают определенной сезонностью. Логично предположить, что пик продаж рассады садовых растений и овощей приходится на начало садово-огородного сезона.
#
# - Средний ценник покупок в разные сезоны отличается.
#
# - Средняя выручка разных сегментов товаров отличается.

# %% [markdown]
# ## 3. Кластеризация товарного ассортимента

# %% [markdown]
# Дадим на ввод модели данные о количестве товара в заказах и цене, чтобы выделить кластеры.

# %%
data.boxplot('revenue', figsize=(3, 12))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Нам необходимо избавиться от крайних аномальных значений, поскольку они не позволяют качественно разделить данные на кластеры.

# %%
data.drop(data[data['quantity'] == 1000].index, inplace=True)

# %%
data_x = data[['price', 'quantity', 'revenue']]

# %%
sc = StandardScaler()
x_sc = sc.fit_transform(data_x)

# %%
linked = linkage(x_sc, method='ward')
plt.figure(figsize=(25, 13))
plt.title('Иерархическая агломерация кластеров товаров', fontsize=14)
dendrogram(linked, orientation='top', leaf_rotation=45., leaf_font_size = 8., truncate_mode='lastp', p=100, color_threshold=80)
plt.show()

# %% [markdown]
# Выделяем два кластера товаров.

# %%
model_km = KMeans(n_clusters = 2, random_state = 0)
labels = model_km.fit_predict(x_sc)

# %%
data['cluster'] = labels
data.groupby('cluster')[['quantity', 'price', 'revenue']].mean()
# Out:
#           quantity        price      revenue
# cluster
# 0         2.082033   332.664958   441.041016
# 1        10.392617  3279.000000  4808.741611

# %%
cluster0 = data[data['cluster'] == 0]
cluster1 = data[data['cluster'] == 1]

# %%
features = data[['quantity', 'price', 'revenue']]

# %%
for feature in features.columns: 
    plt.figure(figsize=(12, 8))
    sns.distplot(cluster0[feature], bins=20, color='C4', label=0)
    sns.distplot(cluster1[feature], bins=5, color='C12', label=1)
    plt.legend(title='Кластер')
    plt.xlabel('')
    plt.title(feature)
    plt.show()

# %% [markdown]
# Графики показывают, что в первом кластере находятся товары, которые чаще берут в маленьких количествах. Цена таких товаров в среднем 332 у.е, но некоторые значения доходят до 2,4 тысяч у.е. Средняя выручка - 441 у.е.
#
# Во второй кластер попали товары, средний ценник которых около 3,2 тысяч. Здесь самые дорогие товары и товары, которые засчет объема продаж дают самую большую выручку. В среднем - 4,8 тысячи у.е.
#
# Посмотрим на количество купленных товарных наименований в кластерах по категориям.

# %%
plt.figure(figsize=(15, 9))
sns.countplot(data=data, x='product_category', hue='cluster', palette=['C4', 'C12', 'C20'], order=data['product_category'].value_counts().index)
plt.xticks(rotation=45, rotation_mode='anchor', ha='right', fontsize=9)
plt.title('Количество оформленных товаров по категориям в кластерах')
plt.xlabel('')
plt.ylabel('')
plt.legend(title='Кластер')
plt.show()

# %% [markdown]
# В первом кластере абсолютное большинство товаров из категорий *Комнатные растения и рассада садовых цветов*, *Посуда*, *Декор, искусственные цветы и подарки*. Товары категории *Рассада овощей, фруктов и зелени* попали исключительно в первый кластер.
#
# Во второй кластер попало больше всего товаров из категорий *Хранение и перемещение*, *Для одежды и обуви*, *Стройка и ремонт*, *Для чистоты и уборки*.

# %% [markdown]
# ***Вывод***

# %% [markdown]
# С помощью модели машинного обучения мы выделили два кластера продуктов.
#
# В первом - товары, которые берут по-разному, в среднем - 1,9 штуки в корзину, цена не превышает 2 тысяч у.е. Сюда попало больше всего товаров из категорий *Комнатные растения и рассада садовых цветов; Посуда; Декор, искусственные цветы и подарки; Рассада овощей, фруктов и зелени*.
#
# Во втором - товары, покупаемые поштучно со средним ценников 3,5 тысячи у.е. Здесь в большинстве своем товары из категорий *Для одежды и обуви, Хранение и перемещение, Стройка и ремонт, Для чистоты и уборки*, а также товары с минимальной стоимостью, но купленные оптом.

# %% [markdown]
# ## 4. Анализ ключевых бизнес-метрик продуктового ассортимента

# %% [markdown]
# Подразумевая наличие сезонности, создадим столбец с временами года.

# %%
def season_func(x):
    if '-01' in x or '02' in x or '12' in x: 
        return 'зима'
    elif '03' in x or '04' in x or '05' in x: 
        return 'весна'
    elif '06' in x or '07' in x or '08' in x:
        return 'лето'
    else:
        return 'осень'
    
data['season'] = data['month'].apply(season_func)

# %% [markdown]
# ### 4.1 Пользовательская активность

# %% [markdown]
# Посмотрим на метрики пользовательской активности.

# %%
dau_total = data.groupby('order_date').agg({'customer_id':'nunique'}).mean()
wau_total = data.groupby('week').agg({'customer_id':'nunique'}).mean()
mau_total = data.groupby('month').agg({'customer_id':'nunique'}).mean()

print('Среднее количество уникальных пользователей в день: {} человек.'.format(int(dau_total)))
print('Среднее количество уникальных пользователей в неделю: {} человек.'.format(int(wau_total)))
print('Среднее количество уникальных пользователей в месяць: {} человек.'.format(int(mau_total)))
# Out:
# Среднее количество уникальных пользователей в день: 6 человек.
# Среднее количество уникальных пользователей в неделю: 43 человек.
# Среднее количество уникальных пользователей в месяць: 187 человек.

# %%
sticky_wau = (dau_total / wau_total) * 100
sticky_mau = (dau_total / mau_total) * 100
print('Недельная аудитория: {:0.2f}%'.format(sticky_wau[0]))
print('Месячная аудитория: {:0.2f}%'.format(sticky_mau[0]))
# Out:
# Недельная аудитория: 15.35%
# Месячная аудитория: 3.52%

# %% [markdown]
# Теперь оценим динамику изменения количества уникальных пользователей во времени.

# %%
data.groupby('order_date').agg({'customer_id':'nunique'}).plot(figsize=(20, 9), color='C8', legend=False)
plt.title('Количество уникальных пользователей в день')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
data.groupby('week').agg({'customer_id':'nunique'}).plot(figsize=(20, 9), color='C8', legend=False)
plt.title('Количество уникальных пользователей в неделю')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
data.groupby('month').agg({'customer_id':'nunique'}).plot(figsize=(20, 9), color='C8', legend=False)
plt.title('Количество уникальных пользователей в месяц')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# В декабре и с февраля по апрель число уникальных покупателей наиболее высоко. В январские праздники спрос на продукцию магазина резко падает. То же самое происходит в июне. Вероятно, в середине дачного сезона уже не принято активно закупаться онлайн. Клиенты либо уже приобрели все необходимое, либо предпочтут офлайн магазин для более скорого результата. Тем не менее, в июле активность среди посетителей растет.
#
# Посмотрим количественную разницу между покупателями в сезонах. В датасете данные за октябрь представлены дважды, поэтому, чтобы не перевешивать значения, выведем срез данных без октября 2018 года.

# %%
data.query('month != "2018-10"').groupby('season').agg(
    {'customer_id':'nunique'}).plot(kind='bar', figsize=(12, 6), color='C8', legend=False)
plt.title('Число покупателей в разное время года')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Летом меньше всего покупателей - чуть меньше 500 человек. Зимой и весной количество уникальных пользователей примерно одинаковое - 600 человек. Попробуем объединить времена года в осенне-зимний и весенне-летний сезоны и сравним их показатели.

# %%
spring_summer = data.query('season == "лето"' and 'season == "весна"')

# %%
autumn_winter = data.query('season == "осень"' and 'season == "зима"')

# %%
def time_func(season):
    if (season == 'лето') or (season == 'весна'):
        return 'ss'
    else: 
        return 'aw'
    
data['year_time'] = data['season'].apply(time_func)

# %% [markdown]
# ### 4.2 Анализ количества заказов

# %%
data.query('month != "2018-10"').groupby('season').agg(
    {'order_id':'nunique'}).plot(kind='bar', figsize=(12, 6), color='C8', legend=False)
plt.title('Число заказов в разное время года')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Зимой наблюдается больше всего заказов. Летом - меньше всего. Посмотрим, как распределились продажи в категориях по сезонам.

# %%
plt.figure(figsize=(12, 7))
sns.countplot(data=data, x='year_time', hue='cluster', palette=['C29', 'C8'])
plt.title('Количество оформленных товаров в разные сезоны в кластерах')
plt.xlabel('')
plt.ylabel('')
plt.legend(title='Кластер')
plt.show()

# %% [markdown]
# В первом кластере больше товаров, купленных в весенне-летний сезон. Во втором - в осенне-зимний период. В целом, в первом кластере сильно больше товаров. Наша задача - понять, когда клиенты приносят больший доход и какие категории товаров в разное время приносят большую прибыль.

# %%
unique_orders = data.pivot_table(
    index='product_category', columns=['cluster', 'year_time'], values='order_id', aggfunc='nunique')
plt.figure(figsize=(15, 15))
sns.heatmap(unique_orders, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Количество уникальных заказов в категориях в разрезе по сегментам и сезонам')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Рассматривая кластеры опосредованно, в первом и зимой, и летом больше всего заказов было оформлено в категории *Комнатные растения и рассада садовых цветов*.
#
# Также зимой популярны покупки в категориях *Для одежды и обуви* (почти в два раза больше, чем летом), *Хранение и перемещение*, *Посуда*, *Для чистоты и уборки*, *Декор, искусственные цветы и подарки*.
#
# Летом клиенты активнее, чем зимой, очевидно, берут *Рассаду овощей, фруктов и зелени*. Кроме того, много заказов из тех же категорий, что и зимой (Кроме *Посуды*). Значения почти равносильны.
#
# В первом кластере товаров зимой чаще берут продукты из категорий *Текстиль*, *Стройка и ремонт*, *Посуда*, *Бытовая техника*.
#
# Во втором кластере больше всего товаров из категорий *Хранение и перемещение*, *Для одежды и обуви*. Сюда почти не входят товары из категорий *Декор*, *Комнатные растения и рассада садовых цветов*, *Бытовая техника*. Совсем нет *Рассады овощей, фруктов и зелени*. Нет летних покупой *Посуды*. В целом, товары из этого кластера покупают больше в осенне-зимний период.

# %%
products_sold = data.pivot_table(
    index='product_category', columns=['cluster', 'year_time'], values='product', aggfunc='count')
plt.figure(figsize=(15, 15))
sns.heatmap(products_sold, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Количество купленных наименований продуктов в разрезе по кластерам и сезонам')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Так как каждый пользователь может купить несколько товаров за раз, количество проданных наименований более наглядно показывает распределение товаров по кластерам.
#
# Значения второго кластера практически не изменились. Эти товары обычно оказываются в корзине в одиночестве. Либо они дорогостоящие, либо покупаются в большом количестве единоразово.
#
# Матрица первого кластера показывает, что разные наименования товаров из категорий *Комнатные растения и рассада садовых цветов* и *Рассада овощей, фруктов и зелени* часто оказываются в одной корзине. Также *Декор*, *Посуду* и товары из категории *Хранение и перемещение* чаще берут по несколько наименований в заказе.

# %% [markdown]
# ### 4.3 Анализ коммерческих показателей: выручка и средний чек

# %% [markdown]
# Найдем общую выручку за весь период и среднюю выручку с заказа.

# %%
print('Суммарная выручка с продаж за период с 1 октября 2018 по 31 октября 2019 составляет {} у.е.'.format(
    data['revenue'].sum()))
# Out:
# Суммарная выручка с продаж за период с 1 октября 2018 по 31 октября 2019 составляет 3411515.0 у.е.

# %%
revenue_avg = data.groupby('customer_id').agg({'revenue':'sum'}).mean()
print('Средний чек заказа: {} у.е.'.format(int(revenue_avg)))
# Out:
# Средний чек заказа: 1425 у.е.

# %% [markdown]
# Посмотрим на динамику выручки за день, месяц, сезон, а также в разрезе по кластерам. Также оценим выручку в различных категориях товаров.

# %%
revenue_per_day = data.pivot_table(index=['order_date', 'cluster'], values=['customer_id', 'revenue'], aggfunc={
    'customer_id':'nunique', 'revenue':'sum'}).reset_index(level='cluster')
revenue_per_month = data.pivot_table(index=['month', 'cluster'], values=['customer_id', 'revenue', 'order_id'], aggfunc={
    'customer_id':'nunique', 'revenue':'sum', 'order_id':'nunique'}).reset_index(level='cluster')
revenue_per_season = data.pivot_table(index=['year_time', 'cluster'], values=['customer_id', 'revenue', 'order_id'], aggfunc={
    'customer_id':'nunique', 'revenue':'sum', 'order_id':'nunique'}).reset_index()

# %%
revenue_per_day.groupby('order_date')['revenue'].sum().plot(figsize=(18, 9), color='C8')
plt.title('Суммарная выручка в день')
plt.xlabel('')
plt.show()

# %% [markdown]
# Наблюдаются несколько крайне удачных дней для магазина. Интересно, что несмотря на то, что в январе была просадка по количеству пользователей, в один из январских дней случилась крупная дневная выручка за период.

# %%
revenue_per_month.groupby('month')['revenue'].sum().plot(figsize=(18, 9), color='C8')
plt.title('Суммарная выручка в месяц')
plt.xlabel('')
plt.show()

# %% [markdown]
# Октябрь 2018 оказался в разы прибыльнее октября 2019. Показатели ноября и декабря наибольшие за период. В феврале и апреле практически одинаковые показатели месячной выручки - 320 тысяч у.е., тогда как в январе, марте и с мая по октябрь показатели доходности сильно упали - минимум в сентябре 170 тысяч у.е.

# %%
revenue_per_season.groupby('year_time').agg({'revenue':'sum'})
# Out:
#              revenue
# year_time
# aw         1976147.0
# ss         1435368.0

# %%
data.query('month != "2018-10"').groupby('year_time').agg({'revenue':'sum'})
# Out:
#              revenue
# year_time
# aw         1625773.0
# ss         1435368.0

# %% [markdown]
# Даже без учета октября 2018, который перекашивает сумму месяцев в сезоне (хотя выручка в этот месяц почти самая высокая), осенне-зимний сезон все равно оказывается прибыльнее весенне-летнего.

# %%
plt.figure(figsize=(18, 9))
revenue_per_day[revenue_per_day['cluster'] == 0]['revenue'].plot(color='C8', label=0)
revenue_per_day[revenue_per_day['cluster'] == 1]['revenue'].plot(color='C22', label=1)
plt.title('Суммарная выручка за день в разбивке по кластерам')
plt.xlabel('')
plt.legend(title='Кластер')
plt.show()

# %%
plt.figure(figsize=(18, 9))
revenue_per_month[revenue_per_month['cluster'] == 0]['revenue'].plot(color='C8', label=0)
revenue_per_month[revenue_per_month['cluster'] == 1]['revenue'].plot(color='C22', label=1)
plt.title('Суммарная выручка за месяц в разбивке по кластерам')
plt.xlabel('')
plt.legend(title='Кластер')
plt.show()

# %% [markdown]
# Заказы товаров второго кластера реже, но дневная выручка их выше. Месячная выручка их, наоборот, ниже.

# %%
plt.figure(figsize=(13, 9))
sns.barplot(data=revenue_per_season, y='revenue', x='year_time', hue='cluster', palette=['C8', 'C20'])
plt.xlabel('')
plt.ylabel('')
plt.title('Суммарная выручка за сезон в разрезе кластеров')
plt.legend(title='Кластер')
plt.show()

# %% [markdown]
# Суммарная выручка за осенне-зимний период выше. Общая сумма проданных товаров первого кластера больше, чем второго.

# %%
revenue_per_category = data.pivot_table(
    index='product_category', columns=['cluster', 'year_time'], values='revenue', aggfunc='sum')
plt.figure(figsize=(15, 15))
sns.heatmap(revenue_per_category, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Суммарная выручка с категории товара в разрезе по кластерам и сезонам')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
avg_revenue_per_category = data.pivot_table(
    index='product_category', columns=['cluster', 'year_time'], values='revenue', aggfunc='mean')
plt.figure(figsize=(15, 15))
sns.heatmap(avg_revenue_per_category, annot=True, fmt='.2f', linewidth=0.1, cmap='viridis')
plt.title('Средняя выручка с категории товара в разрезе по кластерам и сезонам')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# В разрезе по категориям видно, что несмотря на то, что средняя выручка с товаров в категории в первом кластере менее 1000 у.е., суммарная выручка в некоторых категориях первого кластера сопоставима с суммой продаж товаров из второго кластера.
#
# Посмотрим на показатели среднего чека с заказа за весь период и в разрезе по сегментам.

# %%
avg_check = data.groupby('month').agg({'revenue':'sum', 'order_id':'nunique'})
avg_check['revenue_per_order'] = avg_check['revenue'] / avg_check['order_id']

# %%
avg_check.plot(figsize=(18, 9), y='revenue_per_order', color='C8', legend=False)
plt.title('Динамика среднего чека по месяцам')
plt.xlabel('')
plt.show()

# %% [markdown]
# Средний чек за весь исследуемый период сильно упал. Осенью 2018 - зимой 2019 пиковые значения были в районе 1500 у.е. в среднем. В декабре - 1250 у.е., а к марту достиг значений в 1020 у.е. К июню вырос до 1470 у.е, а затем только падал. Минимум в сентябре - менее 1000 у.е. за заказ.

# %%
avg_check_cluster = data.groupby(['month', 'cluster']).agg(
    {'revenue':'sum','customer_id':'nunique','order_id':'nunique'}).reset_index(level='cluster')
avg_check_cluster['revenue_per_order'] = avg_check_cluster['revenue'] / avg_check_cluster['order_id']

# %%
plt.figure(figsize=(18, 9))
avg_check_cluster[avg_check_cluster['cluster'] == 0]['revenue_per_order'].plot(color='C8', label=0)
avg_check_cluster[avg_check_cluster['cluster'] == 1]['revenue_per_order'].plot(color='C22', label=1)
plt.legend(title='Кластер')
plt.xlabel('')
plt.show()

# %% [markdown]
# Средний чек товаров первого кластера доходил до 1000 у.е. в октябре 2018 и в мае 2019. Все остальное время - ниже.
#
# Средний чек заказов товара второго кластера сильно выше. Пик в январе - более 6000 у.е. Также крупные заказы были совершены в апреле и июне. В декабре, марте и сентябре средний чек находился в у отметки в 3800 у.е.

# %%
avg_check_cluster_season = data.groupby(['year_time', 'cluster']).agg(
    {'revenue':'sum', 'order_id':'nunique'}).reset_index(level='cluster').reset_index()
avg_check_cluster_season['revenue_per_order'] = avg_check_cluster_season['revenue'] / avg_check_cluster_season['order_id']

# %%
plt.figure(figsize=(13, 9))
sns.barplot(data=avg_check_cluster_season, y='revenue_per_order', x='year_time', hue='cluster', palette=['C8', 'C20'])
plt.xlabel('')
plt.ylabel('')
plt.title('Средний чек на сезонные товары в разрезе кластеров')
plt.legend(title='Кластер')
plt.show()

# %% [markdown]
# Из гистограммы видно, что сезонность почти не влияет на показатели среднего чека. Летом выручка с заказов товаров второго кластера несколько больше, чем зимняя. Заказы товаров из первого кластера и в осенее-зимний, и в весенне-летний период меньше 1000 у.е. второго - 4800 у.е., 5000 соответственно.

# %% [markdown]
# Также оценим прибыльность товаров из разных категорий и разных периодов покупки. Выведем топ-5 товаров в каждой категории, которые за все время принесли наибольшую выручку магазину и топ-10 товаров, наиболее прибыльных зимой и летом.

# %%
category = data['product_category'].unique()
for i in category:
    display(i, data[data['product_category'] == i].groupby('product').agg(
        {'order_id':'nunique', 'quantity':'sum', 'revenue':'sum'}).sort_values(by='revenue', ascending=False).head(5))
# Out:
# 'Комнатные растения и рассада садовых цветов'
#                                                          order_id  quantity  \
# product
# спатифиллум шопен d-12 см                                       2        46
# пеларгония зональная диам. 12 см сиреневый полумахровый        52        63
# пеларгония розебудная red pandora укорененный черенок          64        79
# пеларгония зональная диам. 12 см красная махровая              21        63
# эвкалипт гунни d-17 см h-60 см                                  6         6
#
#                                                          revenue
# product
# спатифиллум шопен d-12 см                                11512.0
# пеларгония зональная диам. 12 см сиреневый полумахровый  10780.0
# пеларгония розебудная red pandora укорененный черенок    10655.0
# пеларгония зональная диам. 12 см красная махровая        10514.0
# эвкалипт гунни d-17 см h-60 см                            9866.0
# 'Для одежды и обуви'
# ...

# %% [markdown]
# Так, из каждой таблицы видно, сколько товаров было куплено и сколько денег они принесли.
#
# *Комнатные растения и рассада садовых цветов*: товары покупают часто и в больших количествах. Наибольшую выручку имеет спатифиллум шопен, купленный дважды в суммарном количестве 46 штук. Также рассаду герани берут много и часто.
#
# *Для одежды и обуви*: преимущественно здесь товары покупают поштучно. Однако максимальную выручку из этой категории принесли вешалки, купленные 335 раз - выручка 49 тысяч у.е. Также прибыльным товаром является гладильная доска фирмы НИКА, которую купили семь раз. Выручка высокая засчет цены товара. Также в этой категории самый дорогой товар в магазине - уличная сушилка почти за 15 тысяч у.е., купленная один раз.
#
# *Хранение и перемещение* товары также берут поштучно. Самый популярный и самый прибыльный товар из категории - двухколесная сумка-тележка, которую купили 47 раз. Суммарно ее продажи принесли 50 тысяч у.е. В целом, выручку в этой категории приносят сумки-тележки, но видимо, выбор покупателей падает на первую засчет цены. Остальные берут реже, поскольку они дороже.
#
# *Текстиль*: В этой категории самый прибыльный товар в датасете - простынь вафельная, которую купили дважды, но в количестве 30 штук, благодаря чему выручка с ее продаж более 53 тысяч у.е. Также самые прибыльные товары из этой категории те, которые положили в корзину не в единственном числе.
#
# *Рассада овощей, фруктов и зелени*: здесь показатели прибыльности товаров самые низкие, однако стоит учитывать, что в корзине одного покупателя скорей всего окажется много продуктов разных наименований из этой категории.
#
# *Декор, искусственные цветы и подарки*: самые прибыльные товар здесь - муляжи фруктов, которые покупают в сильно больших количествах. Также  среди товаров с наибольшей выручкой здесь оказалась новогодняя ель высотой в 60 см - ее купили девять раз, благодаря чему выручка с товара составила 9400 у.е. В целом, в этой категории товары берут редко, но в больших количествах.
#
# *Стройка и ремонт*: самая большая выручка с набора ножей, купленного в объеме 64 штук и уличной урны, которую однажды купили в количестве пяти штук - более 29 и 24 тысяч у.е. Также в этой категории одни из самых дорогих товаров - стремянки и урны, выручка с которых более 7000 за наименование.
#
# *Посуда*: выручка в этой категории с товара не очень большая, однако их чаще берут не поштучно. Наиболее прибыльные товары - банки и тарелки.
#
# *Для чистоты и уборки*: самый прибыльный товар - придверный коврик, который купили в количестве 54 штуки на сумму почти 17 тысяч у.е. Товары с самой большой выручкой здесь те, которые берут редко, но стоят они дороже.
#
# *Бытовая техника*: в этой категории также маленькая выручка с наименования, поскольку товары берут в единственном числе и редко. Весы напольные и весы электронные с выручкой 2800 за штуку и 2500 за две штуки соответственно возглавляют топ.

# %%
season = data['year_time'].unique()
for i in season:
    display(i, data[data['year_time'] == i].groupby('product').agg(
        {'order_id':'nunique', 'quantity':'sum', 'revenue':'sum'}).sort_values(by='revenue', ascending=False).head(10))
# Out:
# 'aw'
#                                                                                         order_id  \
# product
# простынь вафельная 200х180 см wellness rw180-01 100% хлопок                                    2
# тележка багажная delta тбр-22 синий грузоподъемность 20 кг сумка и 50 кг каркас россия         3
# сумка-тележка 2-х колесная gimi argo синяя                                                    29
# набор ножей attribute chef 5 предметов akf522                                                  1
# урна уличная "гео", hobbyka/хоббика, 59*37,5см, сталь                                          1
# веник сорго с деревянной ручкой с 4-мя швами, rozenbal, r206204                                2
# муляж яблоко 9 см красное                                                                      5
# мусорный контейнер hailo bigbin swing 45 0845-010 45 л хром                                    1
# ...

# %% [markdown]
# Самым прибыльным товаром зимой стала вафельная простынь. Летом - вешалки и двухколесная сумка-тележка, хотя зимой она занимает третье место и ее выручка превышает летнюю более чем на 10 тысяч у.е.

# %% [markdown]
# ***Вывод***

# %% [markdown]
# *Пользовательские метрики:*
#
# - Среднее количество уникальных пользователей в день: 6 человек.
# - Среднее количество уникальных пользователей в неделю: 43 человек.
# - Среднее количество уникальных пользователей в месяць: 187 человек.
#
# - Недельная аудитория: 15.35%
# - Месячная аудитория: 3.52%
#
# - В декабре и с февраля по апрель число уникальных покупателей наиболее высоко. В январские праздники спрос на продукцию магазина резко падает. То же самое происходит в июне. Вероятно, в середине дачного сезона уже не принято активно закупаться онлайн. Клиенты либо уже приобрели все необходимое, либо предпочтут офлайн магазин для более скорого результата. Тем не менее, в июле активность среди посетителей растет.
# - Летом меньше всего покупателей - чуть меньше 500 человек. Зимой и весной количество уникальных пользователей примерно одинаковое - 600 человек.
#
# *Сезонность заказов:*
#
# - Зимой наблюдается больше всего заказов. Летом - меньше всего.
# - В первом кластере больше товаров, кулпенных в весенне-летний сезон. Во втором - в осенне-зимний период.
# - В первом кластере и зимой, и летом больше всего заказов было оформлено в категории *Комнатные растения и рассада садовых цветов.* Также зимой популярны покупки в категориях *Для одежды и обуви (почти в два раза больше, чем летом), Хранение и перемещение, Посуда, Для чистоты и уборки, Декор, искусственные цветы и подарки.*
# - Летом клиенты активнее, чем зимой, очевидно, берут *Рассаду овощей, фруктов и зелени.*
# - В первом кластере товаров зимой чаще берут продукты из категорий *Текстиль, Стройка и ремонт, Посуда, Бытовая техника.*
# - Во втором кластере больше всего товаров из категорий *Хранение и перемещение, Для одежды и обуви.*
# - Разные наименования товаров из категорий *Комнатные растения и рассада садовых цветов* и *Рассада овощей, фруктов и зелени* часто оказываются в одной корзине. Также *Декор, Посуду* и товары из категории *Хранение и перемещение* чаще берут по несколько наименований в заказе.
#
# *Выручка и средний чек:*
#
# - Суммарная выручка с продаж за период с 1 октября 2018 по 31 октября 2019 составляет 3411515.0 у.е.
# - Средняя чек заказа: 1425 у.е.
# - Октябрь 2018 оказался в разы прибыльнее октября 2019. Показатели ноября и декабря наибольшие за период. В феврале и апреле практически одинаковые показатели месячной выручки - 320 тысяч у.е., тогда как в январе, марте и с мая по октябрь показатели доходности сильно упали - минимум в сентябре 170 тысяч у.е.
# - Даже без учета октября 2018, который перекашивает сумму месяцев в сезоне (хотя выручка в этот месяц самая высокая), осенне-зимний сезон все равно оказывается прибыльнее весенне-летнего.
# - Заказы товаров второго кластера реже, но дневная выручка их выше. Месячная выручка их, наоборот, ниже.
# - Суммарная выручка за осенне-зимний период выше.
# - Общая сумма проданных товаров первого кластера больше, чем второго.
# - Несмотря на то, что средняя выручка с товаров в категории в первом кластере менее 1000 у.е., суммарная выручка в некоторых категориях первого кластера сопоставима с суммой продаж товаров из второго кластера.
#
# - Средний чек за весь исследуемый период сильно упал.
# - Осенью 2018 - зимой 2019 пиковые значения были в районе 1500 у.е. в среднем. В декабре - 1250 у.е., а к марту достиг значений в 1020 у.е. К июню вырос до 1470 у.е, а затем только падал. Минимум в сентябре - менее 1000 у.е. за заказ.
# - Средний чек товаров первого кластера доходил до 1000 у.е. в октябре 2018 и в мае 2019. Все остальное время - ниже. Средний чек заказов товара второго кластера сильно выше. Пик в январе - более 6000 у.е. Также крупные заказы были совершены в апреле и июне. В декабре, марте и сентябре средний чек находился в у отметки в 3800 у.е.
# - Сезонность мало влияет на показатели среднего чека. Летом выручка с заказов товаров второго кластера несколько больше, чем зимняя. Заказы товаров из первого кластера и в осенее-зимний, и в весенне-летний период меньше 1000 у.е. второго - 4800 у.е., 5000 соответственно.

# %% [markdown]
# ## 5. Статистический анализ

# %% [markdown]
# ### 5.1 Взаимосвязь кластеров

# %% [markdown]
# Для оценки разницы прибыльности кластеров используем статистические методы анализа.

# %%
cm = data.groupby(['year_time']).corr()
plt.figure(figsize=(15,15))
sns.heatmap(cm, annot=True, linewidth=0.1, fmt='.2f', cmap='viridis')
plt.ylabel('')
plt.title('Матрица корреляции')
plt.show()

# %% [markdown]
# Из матрицы видно, что на показатели кластера влияют как сезонность, так и ряд количественных метрик: выручка, цена товаров. Также наблюдается разная корреляция в сезонах между количеством купленных товаров и выручкой. Соответственно, средний чек тоже является значительной величиной для анализа.

# %% [markdown]
# Сформулируем гипотезы о равенстве кластеров по выручке и среднем чеке и проверим разницу показателей с помощью теста для независимых выборок.

# %% [markdown]
# ### 5.2 Статистический тест на равенство выручек кластеров

# %% [markdown]
# **Нулевая гипотеза:** Выручки разных кластеров товаров равны.
#
# **Альтернативная гипотеза:** Выручки разных кластеров товаров отличаются.

# %% [markdown]
# Для проведения теста необходимо проверить равны ли дисперсии выборок.

# %%
sam_rev_0 = cluster0['revenue']
sam_rev_1 = cluster1['revenue']

# %%
print('Дисперсия выручки 0-го кластера: {}'.format(np.var(sam_rev_0, ddof=1)))
print('Дисперсия выручки 1-го кластера: {}'.format(np.var(sam_rev_1, ddof=1)))
print('Соотношение дисперсий: {}'.format((np.var(sam_rev_1, ddof=1))/(np.var(sam_rev_0, ddof=1))))
# Out:
# Дисперсия выручки 0-го кластера: 314853.2585179409
# Дисперсия выручки 1-го кластера: 24360923.114828374
# Соотношение дисперсий: 77.3723074345767

# %% [markdown]
# Соотношение дисперсий слишком высоко, при проведение теста необходимо учитывать параметр *equal_var*.

# %%
alpha = 0.05 
results = st.ttest_ind(sam_rev_0, sam_rev_1, equal_var=False)
print('p-значение: ', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: между выборками есть значимая разница')
else:
    print('Не получилось отвергнуть нулевую гипотезу, нет оснований считать выборки разными')
# Out:
# p-значение:  2.857109506349008e-39
# Отвергаем нулевую гипотезу: между выборками есть значимая разница

# %%
print('Средняя выручка 0-го кластера: {:.2f}'.format(np.mean(sam_rev_0)))
print('Средняя выручка 1-го кластера: {:.2f}'.format(np.mean(sam_rev_1)))
print('Соотношение между выручками двух кластеров: {:.2f}'.format(np.mean(sam_rev_1) / np.mean(sam_rev_0)))
# Out:
# Средняя выручка 0-го кластера: 441.04
# Средняя выручка 1-го кластера: 4808.74
# Соотношение между выручками двух кластеров: 10.90

# %% [markdown]
# Средние выручки с товаров разных кластеров отличаются практически в 10 раз. Проверим еще выручки с заказов.

# %% [markdown]
# **Нулевая гипотеза:** Выручки с уникальных заказов разных кластеров товаров равны.
#
# **Альтернативная гипотеза:** Выручки с уникальных заказов разных кластеров товаров отличаются.

# %%
sam_ord_rev_0 = data[data['cluster'] == 0].groupby('order_id').agg({'revenue':'sum'})['revenue']
sam_ord_rev_1 = data[data['cluster'] == 1].groupby('order_id').agg({'revenue':'sum'})['revenue']

# %%
print('Дисперсия выручки 0-го кластера: {}'.format(np.var(sam_ord_rev_0, ddof=1)))
print('Дисперсия выручки 1-го кластера: {}'.format(np.var(sam_ord_rev_1, ddof=1)))
print('Соотношение дисперсий: {}'.format((np.var(sam_ord_rev_1, ddof=1))/(np.var(sam_ord_rev_0, ddof=1))))
# Out:
# Дисперсия выручки 0-го кластера: 681650.633082457
# Дисперсия выручки 1-го кластера: 24861399.44698209
# Соотношение дисперсий: 36.47234850286523

# %%
alpha = 0.05 
results = st.ttest_ind(sam_ord_rev_0, sam_ord_rev_1, equal_var=False)
print('p-значение: ', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: между выборками есть значимая разница')
else:
    print('Не получилось отвергнуть нулевую гипотезу, нет оснований считать выборки разными')
# Out:
# p-значение:  1.6125819563341533e-34
# Отвергаем нулевую гипотезу: между выборками есть значимая разница

# %%
print('Средняя выручка с заказа товаров 0-го кластера: {}'.format(np.mean(sam_ord_rev_0)))
print('Средняя выручка с заказа товаров 1-го кластера: {}'.format(np.mean(sam_ord_rev_1)))
print('Соотношение между выручками двух кластеров: {:.2f}'.format(np.mean(sam_ord_rev_1) / np.mean(sam_ord_rev_0)))
# Out:
# Средняя выручка с заказа товаров 0-го кластера: 802.315490673155
# Средняя выручка с заказа товаров 1-го кластера: 4890.80204778157
# Соотношение между выручками двух кластеров: 6.10

# %% [markdown]
# Средние выручки между заказами товаров из разных сегментов отличаются в 6,1 раз - меньше, но разница все еще велика.

# %% [markdown]
# ### 5.3 Статистический тест на равенство среднего чека в кластерах

# %% [markdown]
# **Нулевая гипотеза:** Средние чеки разных кластеров товаров равны.
#
# **Альтернативная гипотеза:** Средние чеки разных кластеров товаров отличаются.

# %%
product_clusters = data.pivot_table(
    index=['order_id','cluster'], values=['product', 'revenue'], aggfunc={'product':'nunique', 'revenue':'sum'}).reset_index()
product_clusters['avg_check'] = product_clusters['revenue'] / product_clusters['product']

# %%
sam_check_0 = product_clusters[product_clusters['cluster'] == 0]['avg_check']
sam_check_1 = product_clusters[product_clusters['cluster'] == 1]['avg_check']

# %% [markdown]
# Также проверим дисперсии выборок.

# %%
print('Дисперсия среднего чека 0-го кластера: {}'.format(np.var(sam_check_0, ddof=1)))
print('Дисперсия среднего чека 1-го кластера: {}'.format(np.var(sam_check_1, ddof=1)))
print('Соотношение дисперсий: {}'.format((np.var(sam_check_1, ddof=1))/(np.var(sam_check_0, ddof=1))))
# Out:
# Дисперсия среднего чека 0-го кластера: 408847.2885046791
# Дисперсия среднего чека 1-го кластера: 24725454.062345132
# Соотношение дисперсий: 60.476013312393924

# %%
alpha = 0.05 
results = st.ttest_ind(sam_check_0, sam_check_1, equal_var=False)
print('p-значение: ', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: между выборками есть значимая разница')
else:
    print('Не получилось отвергнуть нулевую гипотезу, нет оснований считать выборки разными')
# Out:
# p-значение:  6.341813638342744e-36
# Отвергаем нулевую гипотезу: между выборками есть значимая разница

# %%
print('Значение среднего чека в 0-ом кластере: {:.2f}'.format(np.mean(sam_check_0)))
print('Значение среднего чека в 1-ом кластере: {:.2f}'.format(np.mean(sam_check_1)))
print('Соотношение между средними чеками двух кластеров: {:.2f}'.format(np.mean(sam_check_1) / np.mean(sam_check_0)))
# Out:
# Значение среднего чека в 0-ом кластере: 643.14
# Значение среднего чека в 1-ом кластере: 4830.56
# Соотношение между средними чеками двух кластеров: 7.51

# %% [markdown]
# Средний чек также статистически сильно отличается в кластерах.

# %% [markdown]
# ***Вывод***

# %% [markdown]
# Статистический анализ показывает, что между сегментами есть весомая разница как в показателях средней выручки с товара и заказа, так и среднего чека.

# %% [markdown]
# ## 6. Выводы и рекомендации

# %% [markdown]
# Мы располагаем данными за период с 2018-10-01 по 2019-10-31. Полагая, что для ассортимента магазина характерна сезонность, выделили осенне-зимний и весенне-летний сезон.
#
# ***Показатели пользовательской активности***
#
# - Всего уникальных пользователей в датасете: 2451
# - Среднее количество уникальных пользователей в день: 6 человек.
# - Среднее количество уникальных пользователей в неделю: 43 человека.
# - Среднее количество уникальных пользователей в месяц: 187 человек.
# - Недельная аудитория: 15.35%
# - Месячная аудитория: 3.52%
# - Пик месячной аудитории наблюдается в декабре и с февраля по январь. Летом покупателей меньше всего.
#
# ***Категоризация товарного ассортимента***
#
# - Всего в датасете 2329 уникальных продукта.
# - В ходе анализа было выделено 10 категорий товаров:
#
#
#     - Рассада овощей, фруктов и зелени
#     - Комнатные растения и рассада садовых цветов
#     - Декор, искусственные цветы и подарки
#     - Товары для ухода за одеждой и обувью
#     - Товары для строительства и ремонта
#     - Бытовая техника
#     - Хранение и перемещение
#     - Товары для чистоты и уборки
#     - Посуда и кухонная утварь
#     - Текстиль
#
# - Всего уникальных заказов в датасете: 2784.
# - Товары с наибольшим количеством заказов в категориях: *Комнатные растения и рассада садовых цветов* и *Для одежды и обуви*.
# - С наименьшим - *Бытовая техника* и *Текстиль*.
#
# *Рассада овощей, фруктов и зелени:* здесь показатели прибыльности товаров самые низкие, однако стоит учитывать, что в корзине одного покупателя скорей всего окажется много продуктов разных наименований из этой категории.
#
# *Комнатные растения и рассада садовых цветов:* товары покупают часто и в больших количествах. Наибольшую выручку имеет спатифиллум шопен, купленный дважды в суммарном количестве 46 штук. Также рассаду герани берут много и часто.
#
# *Декор, искусственные цветы и подарки:* самые прибыльные товар здесь - муляжи фруктов, которые покупают в сильно больших количествах. Также среди товаров с наибольшей выручкой здесь оказалась новогодняя ель высотой в 60 см - ее купили девять раз, благодаря чему выручка с товара составила 9400 у.е. В целом, в этой категории товары берут редко, но в больших количествах.
#
# *Для одежды и обуви:* преимущественно здесь товары покупают поштучно. Однако максимальную выручку из этой категории принесли вешалки, купленные 335 раз - выручка 49 тысяч у.е. Также прибыльным товаром является гладильная доска фирмы НИКА, которую купили семь раз.
#
# *Стройка и ремонт:* самая большая выручка с набора ножей, купленного в объеме 64 штук и уличной урны, которую однажды купили в количестве пяти штук - более 29 и 24 тысяч у.е. Также в этой категории одни из самых дорогих товаров - стремянки и урны, выручка с которых более 7000 за наименование.
#
# *Бытовая техника:* в этой категории также маленькая выручка с наименования, поскольку товары берут в единственном числе и редко. Весы напольные и весы электронные с выручкой 2800 за штуку и 2500 за две штуки соответственно возглавляют топ.
#
# *Хранение и перемещение:* товары также берут поштучно. Самый популярный и самый прибыльный товар из категории - двухколесная сумка-тележка, которую купили 47 раз. Суммарно ее продажи принесли 50 тысяч у.е. В целом, выручку в этой категории приносят сумки-тележки, но видимо, выбор покупателей падает на первую засчет цены. Остальные берут реже, поскольку они дороже.
#
# *Для чистоты и уборки:* самый прибыльный товар - придверный коврик, который купили в количестве 54 штуки на сумму почти 17 тысяч у.е. Товары с самой большой выручкой здесь те, которые берут редко, но стоят они дороже.
#
# *Посуда:* выручка в этой категории с товара не очень большая, однако их чаще берут не поштучно. Наиболее прибыльные товары - банки и тарелки.
#
# *Текстиль:* В этой категории самый прибыльный товар в датасете - простынь вафельная, которую купили дважды, но в количестве 30 штук, благодаря чему выручка с ее продаж более 53 тысяч у.е. Также самые прибыльные товары из этой категории те, которые положили в корзину не в единственном числе.
#
# ***Кластеризация товарного ассортимента***
#
# С помощью модели KMeans выделили 2 кластера продуктов.
#
# *Первый:* товары, которые берут по-разному, в среднем - 1,9 штуки в корзину, цена не превышает 2 тысяч у.е. Сюда попало больше всего товаров из категорий *Комнатные растения и рассада садовых цветов; Посуда; Декор, искусственные цветы и подарки; Рассада овощей, фруктов и зелени.*
# *Второй:* товары, покупаемые поштучно со средним ценников 3,5 тысячи у.е. Здесь в большинстве своем товары из категорий *Для одежды и обуви; Хранение и перемещение; Стройка и ремонт; Для чистоты и уборки*, а также товары с минимальной стоимостью, но купленные оптом.
#
# ***Коммерческие показатели в разрезе по кластерам и сезонам***
#
# *Выручка и средний чек:*
#
# - Самый высокий ценник на товары в категории *Хранение и перемещение* - 1700 у.е. в среднем. Средний ценник в 1000 у.е. превышают товары из категорий *Для одежды и обуви; Стройка и ремонт; Бытовая техника*. В последних двух заметен значительный разброс цен между товарами. Меньше всего стоят товары из категорий *Рассада овощей, фруктов и зелени; Декор, искусственные цветы и подарки* (около 100 у.е.) и *Комнатные растения и рассада садовых цветов* (менее 200 у.е.).
# - Стоимость товаров в корзине в среднем 462 у.е. Большинство купленных товаров не превышают цену в 3075 у.е. Тем не менее, мы так же можем наблюдать выбивающиеся значения - 156 товаров стоят больше обозначенного ценника.
# - Зимой наблюдается больше всего заказов. Летом - меньше всего.
# - В первом кластере больше товаров, купленных в весенне-летний сезон. Во втором - в осенне-зимний период.
# - В первом кластере и зимой, и летом больше всего заказов было оформлено в категории *Комнатные растения и рассада садовых цветов.* Также зимой популярны покупки в категориях *Для одежды и обуви (почти в два раза больше, чем летом), Хранение и перемещение, Посуда, Для чистоты и уборки, Декор, искусственные цветы и подарки.*
# - Летом клиенты активнее, чем зимой, очевидно, берут *Рассаду овощей, фруктов и зелени.*
# - В первом кластере товаров зимой чаще берут продукты из категорий *Текстиль, Стройка и ремонт, Посуда, Бытовая техника.*
# - Во втором кластере больше всего товаров из категорий *Хранение и перемещение, Для одежды и обуви.*
# - Разные наименования товаров из категорий *Комнатные растения и рассада садовых цветов* и *Рассада овощей, фруктов и зелени* часто оказываются в одной корзине. Также *Декор, Посуду* и товары из категории *Хранение и перемещение* чаще берут по несколько наименований в заказе.
#
#
# - Суммарная выручка с продаж за период с 1 октября 2018 по 31 октября 2019 составляет 3411515.0 у.е.
# - Показатели выручки ноября и декабря наибольшие за период. В феврале и апреле практически одинаковые показатели месячной выручки - 320 тысяч у.е., тогда как в январе, марте и с мая по октябрь показатели доходности сильно упали - минимум в сентябре 170 тысяч у.е.
# - Осенне-зимний сезон прибыльнее весенне-летнего.
# - Заказы товаров второго кластера реже, но дневная выручка их выше. Месячная выручка их, наоборот, ниже.
# - Суммарная выручка за осенне-зимний период выше.
# - Общая сумма проданных товаров первого кластера больше, чем второго.
# - Несмотря на то, что средняя выручка с товаров в категории в первом кластере менее 1000 у.е., суммарная выручка в некоторых категориях первого кластера сопоставима с суммой продаж товаров из второго кластера.
#
#
# - Средний чек заказа: 1425 у.е.
# - Осенью 2018 - зимой 2019 пиковые значения среднего чека были в районе 1500 у.е. в среднем. В декабре - 1250 у.е., а к марту средний чек достиг значений в 1020 у.е. К июню вырос до 1470 у.е, а затем только падал. Минимум в сентябре - менее 1000 у.е. за заказ.
# - Средний чек товаров первого кластера доходил до 1000 у.е. в октябре 2018 и в мае 2019. Все остальное время - ниже. Средний чек заказов товара второго кластера сильно выше. Пик в январе - более 6000 у.е. Также крупные заказы были совершены в апреле и июне. В декабре, марте и сентябре средний чек находился в у отметки в 3800 у.е.
# - Сезонность мало влияет на показатели среднего чека. Летом выручка с заказов товаров второго кластера несколько больше, чем зимняя. Заказы товаров из первого кластера и в осенее-зимний, и в весенне-летний период меньше 1000 у.е. второго - 4800 у.е., 5000 соответственно.
#
# ***Проверка статистических гипотез***
#
# На коммерческие показатели кластера влияют как сезонность, так и ряд количественных метрик: выручка, цена товаров.
# Наблюдается разная корреляция в сезонах между количеством купленных товаров и выручкой. Соответственно, средний чек тоже является значительной величиной для анализа.
#
# Между сегментами есть весомая разница как в показателях средней выручки с товара и заказа, так и среднего чека.
#
#     Средняя выручка 0-го кластера: 441.04
#     Средняя выручка 1-го кластера: 4808.74
#     Соотношение между выручками двух кластеров: 10.90
#
#     Значение среднего чека в 0-ом кластере: 643.14
#     Значение среднего чека в 1-ом кластере: 4830.56
#     Соотношение между средними чеками двух кластеров: 7.51
#
# Несмотря на то, что в первом кластере средняя выручка и средний чек в разы меньше, чем во втором, картина суммарной выручки обратная. Товаров из первого кластера за весь период купили на 500 тысяч у.е. чем второго. Заказы товаров из первого кластера совершают чаще и в больших количествах.
#
# ***Рекомендации:***
#
# - Внимание аудитории к магазину, как и показатели прибыльности за год снизились. Ключевая задача - повысить пользовательские метрики.
# - Необходимо выстраивать гибкую маркетинговую стратегию, основанную на сезонности пользовательских предпочтений.
# - Кроме того, необходимо повысить средний чек заказа.
# - Дешевые мелкие товары в итоге оказываются прибыльнее дорогих, особенно стоит учитывать, что разные наименования товаров из категорий *Комнатные растения и рассада садовых цветов* и *Рассада овощей, фруктов и зелени* часто оказываются в одной корзине. Реже - товары из категорий *Декор, Посуда* и *Хранение и перемещение*.
# - Несмотря на то, что летом покупателей меньше, ни средний чек, ни показатели выручки не уступают зимним. Это происходит потому, что "летние" товары зачастую берут в больших объемах. Так, весной-летом стоит делать упор на рекламу товаров из категорий *Рассада овощей, фруктов и зелени*; *Комнатные растения и рассада садовых цветов*; *Хранение и перемещение*.
# - Зимой популярны покупки в категориях *Для одежды и обуви (почти в два раза больше, чем летом); Хранение и перемещение; Посуда; Стройка и ремонт; Текстиль.* *Комнатные цветы* (вероятно, их стоит рассматривать как подкатегорию) не менее часто берут зимой.

# %% [markdown]
# **Ссылка на дашборд:** https://public.tableau.com/app/profile/daria6509/viz/FinalPraktikumProject/sheet3#1

# %% [markdown]
# **Ссылка на презентацию:** https://drive.google.com/file/d/1YscF_Vxg573cLOm5sQkRwqV5BFlTDVOy/view?usp=sharing
